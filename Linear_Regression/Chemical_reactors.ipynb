# %%
a = 100
b = 50
c = 0
t = 0.1
k1 = 0.008
k2 = 0.002

for i in range(50):
    print("a = ", a, "b =", b, "c = ", c)
    a = a + (k2 * c -k1 * a *b) * t
    b = b + (k2 * c -k1 * a *b) * t
    c = c + (2 * k1 * a *b - k2 * c) * t
# Out:
# a =  100 b = 50 c =  0
# a =  96.0 b = 46.16 c =  7.090176
# a =  92.4563300352 b = 42.74719067966013 c =  13.412355356090053
# a =  89.29721381062619 b = 39.69610912999117 c =  19.081275996108072
# a =  86.4652285102808 b = 36.95405886767541 c =  24.189845571910325
# a =  83.91387356389444 b = 34.478130257993925 c =  28.814117143898002
# a =  81.6050816167722 b = 32.23302057446487 c =  33.01695956004411
# a =  79.50738238889676 b = 30.189413492486352 c =  36.85080615636191
# a =  77.59452755601312 b = 28.32275703200354 c =  40.35974151670194
# a =  75.84444674353081 b = 26.61232991043188 c =  43.58110547017944
# a =  74.23844501373443 b = 25.04051973893155 c =  46.5467400454918
# a =  72.76057896354033 b = 23.592258915938555 c =  49.283968965933
# a =  71.39716662310836 b = 22.25457935706232 c =  51.8163744289132
# a =  70.13639876960745 b = 21.016257790158665 c =  54.164418573252114
# a =  68.96802794370976 b = 19.86753079023822 c =  56.34594475947932
# ...
